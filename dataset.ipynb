# %%
import pandas as pd
df = pd.read_csv("Schemes.csv")

# %%
df
# Out:
#         scheme_code  4_month_rolling_return  monthly_return  \
# 0            100033               -0.046557       -0.047665
# 1            100033               -0.129687       -0.090593
# 2            100033               -0.024333        0.112084
# 3            100033               -0.001230        0.037002
# 4            100033                0.076887        0.026821
# ...             ...                     ...             ...
# 703664       151594                0.038505        0.007187
# 703665       151595                0.038473        0.007187
# 703666       151596                0.039027        0.007314
# 703667       151597                0.039029        0.007315
# 703668       151604                0.142696        0.008422
#
#         variance_of_monthly_returns  max_drawdown  drawdown_duration  \
# 0                          0.001033     -0.093623                6.0
# 1                          0.001643     -0.175734                7.0
# ...

# %%
df.columns
# Out:
# Index(['scheme_code', '4_month_rolling_return', 'monthly_return',
#        'variance_of_monthly_returns', 'max_drawdown', 'drawdown_duration',
#        'excess_return', 'sharpe_ratio', 'downside_return', 'sortino_ratio',
#        'annualized_return', 'volatility', 'downside_deviation', 'max_gain',
#        'CAGR', 'recovery_time', 'nav'],
#       dtype='object')
